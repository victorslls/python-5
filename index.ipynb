# %%
range(1,5)
# Out:
# range(1, 5)

# %%
def funcaoLeitura():
    for num in [1,2,3,4,5]:
        print("Número", num)

funcaoLeitura()
# Out:
# Número 1
# Número 2
# Número 3
# Número 4
# Número 5

# %%
def funcaoLeituraa():
    for num in range(5):
        print("Número", num)

funcaoLeituraa()
# Out:
# Número 0
# Número 1
# Número 2
# Número 3
# Número 4

# %%
def addNum(n1, n2):
    print("O primeiro número é: ", n1)
    print("O Segundo número é: ", n2)
    print("A Soma número é: ", n1+n2)

addNum(2,5)
addNum(4,6) 
addNum(6,2)
# Out:
# O primeiro número é:  2
# O Segundo número é:  5
# A Soma número é:  7
# O primeiro número é:  4
# O Segundo número é:  6
# A Soma número é:  10
# O primeiro número é:  6
# O Segundo número é:  2
# A Soma número é:  8

# %%
varGlobal = 10
def multiplica(num1, num2):
    varLocal = num1 * num2
    print("Variável da função Multiplica:", varLocal)
    print(varLocal)
    print(varGlobal)
 

multiplica(20,40)    
print(varGlobal)
# Out:
# Variável da função Multiplica: 800
# 800
# 10
# 10

# %%
varGlobal =10 
def multiplicacao(n1,n2):
    varGlobal= (n1*n2)
    print("Variável da função Multiplica:", varGlobal)



multiplicacao(5,3)
print(varGlobal)
# Out:
# Variável da função Multiplica: 15
# 10

# %%
def variosParametros(*parametros):
    for n, item in enumerate(parametros):
        print("Parâmetro", n, item)
    
    return

variosParametros('Luquinhas', 'Madá', 'Giggio')
# Out:
# Parâmetro 0 Luquinhas
# Parâmetro 1 Madá
# Parâmetro 2 Giggio

# %%
def soma (n1,n2):
    return n1+n2

def subtrai (n1,n2):
    return n1-n2

def multiiplica (n1,n2):
    return n1*n2

def dividir (n1,n2):
    return n1/n2

# %%
while True:
    print('+================+')
    print(' | Menu de Operçaões')
    print(' | 1 - somar')
    print(' | 2 - subtrair')
    print(' | 3 - multiplicar')
    print(' | 4 - dividir')
    print(' | 0 - sair')
    print('+================+')
    

    op = int(input())
    if op==0:
        break
    n1 = int(input("Primeiro número: "))
    n2 = int(input("Segundo número: "))

    if op==1:
        print("O resultado da soma é: ", soma(n1,n2))
    if op==2:
        print("O resultado da subtração é: ", subtrai(n1,n2))
    
    elif op==3:
        print("O resultado da multiplicado é: ", multiiplica(n1,n2))
    elif op==4:
        print("O resultado da divisão é: ", dividir(n1,n2))

    else: print('opção não existe')
# Out:
# +================+
#  | Menu de Operçaões
#  | 1 - somar
#  | 2 - subtrair
#  | 3 - multiplicar
#  | 4 - dividir
#  | 0 - sair
# +================+
# opção não existe
# +================+
#  | Menu de Operçaões
#  | 1 - somar
#  | 2 - subtrair
#  | 3 - multiplicar
#  | 4 - dividir
#  | 0 - sair
# +================+
# opção não existe
# +================+
#  | Menu de Operçaões
#  | 1 - somar
#  | 2 - subtrair
#  | 3 - multiplicar
#  | 4 - dividir
#  | 0 - sair
# +================+
